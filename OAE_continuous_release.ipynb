# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
#%matplotlib widget

import cmocean
import glob

import os

import math
from datetime import timedelta, datetime
from operator import attrgetter

from datetime import timedelta as delta

import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.io.img_tiles as cimgt
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter

import pop_tools
from scipy.optimize import curve_fit

# %%
grid = pop_tools.get_grid('POP_gx1v7')[['TAREA', 'KMT', 'TLAT', 'TLONG', 'REGION_MASK']]

# %%
def process(da):
    
    da['ALK_excess'] = da.ALK - da.ALK_ALT_CO2
    da['DIC_excess'] = da.DIC - da.DIC_ALT_CO2
    da['pCO2_SURF_excess'] = da.pCO2SURF - da.pCO2SURF_ALT_CO2
    
    return da

# %% [markdown]
# Read data

# %%
#fpath = '/glade/scratch/mclong/OAE-Global-Efficiency/archive/smyle-fosi.North_Atlantic_basin_yearlong.alk-forcing-North_Atlantic_basin_yearlong.063-01/ocn/hist/'

# fpath = '/glade/scratch/eyankovsky/archive/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.036-5year/ocn/hist/'
# da = xr.open_mfdataset(fpath + 'smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.036-5year.pop.h.*.nc')

fpath = '/glade/scratch/eyankovsky/archive/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.063-5year/ocn/hist/'
da = xr.open_mfdataset(fpath + 'smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.063-5year.pop.h.*.nc')
print(da)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     198             try:
# --> 199                 file = self._cache[self._key]
#     200             except KeyError:
#
# ~/.local/lib/python3.7/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/glade/scratch/eyankovsky/archive/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.063-5year/ocn/hist/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.063-5year.pop.h.0351-04.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False))]
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /glade/derecho/scratch/eyankovsky/tmp/ipykernel_72400/632366681.py in <module>
#       5
#       6 fpath = '/glade/scratch/eyankovsky/archive/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.063-5year/ocn/hist/'
# ----> 7 da = xr.open_mfdataset(fpath + 'smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.063-5year.pop.h.*.nc')
#       8 print(da)
#
# ~/.local/lib/python3.7/site-packages/xarray/backends/api.py in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#     944                 coords=coords,
#     945                 join=join,
# --> 946                 combine_attrs=combine_attrs,
#     947             )
#     948         else:
#
# ~/.local/lib/python3.7/site-packages/xarray/core/combine.py in combine_by_coords(datasets, compat, data_vars, coords, fill_value, join, combine_attrs)
#     799             fill_value=fill_value,
#     800             join=join,
# --> 801             combine_attrs=combine_attrs,
#     802         )
#     803
#
# ~/.local/lib/python3.7/site-packages/xarray/core/combine.py in _combine_nd(combined_ids, concat_dims, data_vars, coords, compat, fill_value, join, combine_attrs)
#     223             fill_value=fill_value,
#     224             join=join,
# --> 225             combine_attrs=combine_attrs,
#     226         )
#     227     (combined_ds,) = combined_ids.values()
#
# ~/.local/lib/python3.7/site-packages/xarray/core/combine.py in _combine_all_along_first_dim(combined_ids, dim, data_vars, coords, compat, fill_value, join, combine_attrs)
#     252         datasets = combined_ids.values()
#     253         new_combined_ids[new_id] = _combine_1d(
# --> 254             datasets, dim, compat, data_vars, coords, fill_value, join, combine_attrs
#     255         )
#     256     return new_combined_ids
#
# ~/.local/lib/python3.7/site-packages/xarray/core/combine.py in _combine_1d(datasets, concat_dim, compat, data_vars, coords, fill_value, join, combine_attrs)
#     282                 fill_value=fill_value,
#     283                 join=join,
# --> 284                 combine_attrs=combine_attrs,
#     285             )
#     286         except ValueError as err:
#
# ~/.local/lib/python3.7/site-packages/xarray/core/concat.py in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     237         )
#     238     return f(
# --> 239         objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs
#     240     )
#     241
#
# ~/.local/lib/python3.7/site-packages/xarray/core/concat.py in _dataset_concat(datasets, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     506             except KeyError:
#     507                 raise ValueError(f"{k!r} is not present in all datasets.")
# --> 508             combined = concat_vars(vars, dim, positions, combine_attrs=combine_attrs)
#     509             assert isinstance(combined, Variable)
#     510             result_vars[k] = combined
#
# ~/.local/lib/python3.7/site-packages/xarray/core/variable.py in concat(variables, dim, positions, shortcut, combine_attrs)
#    2856         along the given dimension.
#    2857     """
# -> 2858     variables = list(variables)
#    2859     if all(isinstance(v, IndexVariable) for v in variables):
#    2860         return IndexVariable.concat(variables, dim, positions, shortcut, combine_attrs)
#
# ~/.local/lib/python3.7/site-packages/xarray/core/concat.py in ensure_common_dims(vars)
#     495             if var.dims != common_dims:
#     496                 common_shape = tuple(dims_sizes.get(d, dim_len) for d in common_dims)
# --> 497                 var = var.set_dims(common_dims, common_shape)
#     498             yield var
#     499
#
# ~/.local/lib/python3.7/site-packages/xarray/core/variable.py in set_dims(self, dims, shape)
#    1459             dims_map = dict(zip(dims, shape))
#    1460             tmp_shape = tuple(dims_map[d] for d in expanded_dims)
# -> 1461             expanded_data = duck_array_ops.broadcast_to(self.data, tmp_shape)
#    1462         else:
#    1463             expanded_data = self.data[(None,) * (len(expanded_dims) - self.ndim)]
#
# ~/.local/lib/python3.7/site-packages/xarray/core/variable.py in data(self)
#     345             return self._data
#     346         else:
# --> 347             return self.values
#     348
#     349     @data.setter
#
# ~/.local/lib/python3.7/site-packages/xarray/core/variable.py in values(self)
#     518     def values(self):
#     519         """The variable's data as a numpy.ndarray"""
# --> 520         return _as_array_or_item(self._data)
#     521
#     522     @values.setter
#
# ~/.local/lib/python3.7/site-packages/xarray/core/variable.py in _as_array_or_item(data)
#     260     TODO: remove this (replace with np.asarray) once these issues are fixed
#     261     """
# --> 262     data = data.get() if isinstance(data, cupy_array_type) else np.asarray(data)
#     263     if data.ndim == 0:
#     264         if data.dtype.kind == "M":
#
# ~/.local/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~/.local/lib/python3.7/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     669
#     670     def __array__(self, dtype=None):
# --> 671         return np.asarray(self.array, dtype=dtype)
#     672
#     673     def __getitem__(self, key):
#
# ~/.local/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~/.local/lib/python3.7/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     570     def __array__(self, dtype=None):
#     571         array = as_indexable(self.array)
# --> 572         return np.asarray(array[self.key], dtype=None)
#     573
#     574     def transpose(self, order):
#
# ~/.local/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in __getitem__(self, key)
#      90     def __getitem__(self, key):
#      91         return indexing.explicit_indexing_adapter(
# ---> 92             key, self.shape, indexing.IndexingSupport.OUTER, self._getitem
#      93         )
#      94
#
# ~/.local/lib/python3.7/site-packages/xarray/core/indexing.py in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#     861     """
#     862     raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# --> 863     result = raw_indexing_method(raw_key.tuple)
#     864     if numpy_indices.tuple:
#     865         # index the loaded np.ndarray
#
# ~/.local/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in _getitem(self, key)
#     101         try:
#     102             with self.datastore.lock:
# --> 103                 original_array = self.get_array(needs_lock=False)
#     104                 array = getitem(original_array, key)
#     105         except IndexError:
#
# ~/.local/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in get_array(self, needs_lock)
#      80
#      81     def get_array(self, needs_lock=True):
# ---> 82         ds = self.datastore._acquire(needs_lock)
#      83         variable = ds.variables[self.variable_name]
#      84         variable.set_auto_maskandscale(False)
#
# ~/.local/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in _acquire(self, needs_lock)
#     381
#     382     def _acquire(self, needs_lock=True):
# --> 383         with self._manager.acquire_context(needs_lock) as root:
#     384             ds = _nc4_require_group(root, self._group, self._mode)
#     385         return ds
#
# /glade/work/eyankovsky/conda-envs/mcdr/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~/.local/lib/python3.7/site-packages/xarray/backends/file_manager.py in acquire_context(self, needs_lock)
#     185     def acquire_context(self, needs_lock=True):
#     186         """Context manager for acquiring a file."""
# --> 187         file, cached = self._acquire_with_cache_info(needs_lock)
#     188         try:
#     189             yield file
#
# ~/.local/lib/python3.7/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     203                     kwargs = kwargs.copy()
#     204                     kwargs["mode"] = self._mode
# --> 205                 file = self._opener(*self._args, **kwargs)
#     206                 if self._mode == "w":
#     207                     # ensure file doesn't get overriden when opened again
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# src/netCDF4/_netCDF4.pyx in genexpr()
#
# src/netCDF4/_netCDF4.pyx in genexpr()
#
# /glade/work/eyankovsky/conda-envs/mcdr/lib/python3.7/site-packages/netCDF4/utils.py in _find_dim(grp, dimname)
#      32     return [A[i] for i in sorted(range(len(A)), key=B.__getitem__)]
#      33
# ---> 34 def _find_dim(grp, dimname):
#      35     # find Dimension instance given group and name.
#      36     # look in current group, and parents.
#
# KeyboardInterrupt:

# %%
da = process(da)

# %%
def excess_dic(da):
    
    dic_inv = ((da.DIC - da.DIC_ALT_CO2) * da.dz * da.TAREA).sum(['z_t', 'nlat', 'nlon']) * 1e-9
    dic_inv = dic_inv.compute()
    
    return dic_inv

# %%
def cal_added_ALk(da):
    '''Total added ALK, in mol'''
    ALk_added_total = (da.ALK_FLUX * da.TAREA).sum(['time', 'nlat', 'nlon'])*1e-9*86400*31  # mol/month sum all months
    return ALk_added_total.values

# %%
total_exc_alk = cal_added_ALk(da)

exc_dic = excess_dic(da)
ALk_added = (da.ALK_FLUX * da.TAREA).sum(['nlat', 'nlon'])*1e-9*86400*31  # mol/month sum all months

# %%
fig = plt.figure(figsize=(12,3))
ax = fig.add_subplot(131)
ax.plot(ALk_added.time, ALk_added.values, marker='.', label='Atlantic63')
ax.set_title('ALK_FLUX')
ax.set_ylabel('ALK_FLUX (mol/month)')
ax.set_xlabel('Time')

ax1 = fig.add_subplot(132)
ax1.plot(exc_dic.time, exc_dic, marker='.', label='Atlantic63')
ax1.set_ylabel('DIC inventory (mol)')
ax1.set_xlabel('Time')
ax1.set_title('DIC inventory')

ax2 = fig.add_subplot(133)
ax2.plot(exc_dic.time, exc_dic/total_exc_alk, marker='.', label='Atlantic63')
ax2.set_ylabel('excess DIC (mol) / added ALk (mol)')
ax2.set_xlabel('Time')
ax2.set_title('OAE efficiency')


ax.set_xlim(da.time.values[0] - timedelta(days=30), da.time.values[-1] + timedelta(days=30))
ax1.set_xlim(da.time.values[0] - timedelta(days=30), da.time.values[-1] + timedelta(days=30))
ax2.set_xlim(da.time.values[0] - timedelta(days=30), da.time.values[-1] + timedelta(days=30))

ax.legend()
ax1.legend()
ax2.legend()

plt.subplots_adjust(wspace=0.3)


# plt.savefig('/glade/work/mengyangz/GVP/figures/check_000_ALK_DIC_eff.png', 
#             dpi=200, bbox_inches='tight')

# %%
def plot(da, tstep):
    
        fig = plt.figure(figsize=(10,10))

        ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
        ax.stock_img()
        ax.coastlines(linewidth=0.5, color='blue', resolution='110m')

        sca = ax.pcolormesh(grid.TLONG,
                      grid.TLAT,
                      da.isel(time=tstep, z_t=0).ALK_excess,
                      transform=ccrs.PlateCarree(),
                      cmap=cmocean.cm.dense,vmin=0,vmax=.5);
        cb = fig.colorbar(sca, ax=ax, shrink=0.74)
        cb.ax.set_title('meq/m^2')


        ax.set_extent([-110, 30, -50, 80], ccrs.PlateCarree())
        ax.set_xticks(np.arange(-110, 30, 10), crs=ccrs.PlateCarree())
        ax.set_yticks(np.arange(-50, 80, 10), crs=ccrs.PlateCarree())
        lon_formatter = LongitudeFormatter(zero_direction_label=False)
        lat_formatter = LatitudeFormatter()
        ax.xaxis.set_major_formatter(lon_formatter)
        ax.yaxis.set_major_formatter(lat_formatter)  

        ax.stock_img()
        ax.add_feature(cfeature.LAND, facecolor='lightgray')

        ax.set_title('excess_ALK at surface ' + str(da.time.values[tstep])[:10], loc='left')

    #     plt.close()

    #     fig.savefig(f'/glade/work/mengyangz/GVP/figures/figs2movies/Atlantic000/{tstep:04d}.png', dpi=300, bbox_inches='tight')

# %%
plot(da, -1)

# %%
plot(da063_01, -1)

# %%
ALk_added = (da.ALK_FLUX * da.TAREA).sum(['nlat', 'nlon'])*1e-9*86400*31  # mol/month sum all months
exc_dic = excess_dic(da)

# %%
# fpath = '/glade/scratch/mengyangz/archive/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.063-1999-01/ocn/hist/'
# da063_01 = xr.open_mfdataset(fpath + 'smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.063-1999-01.pop.h.*.nc')
# da063_01 = process(da063_01)


# fpath = '/glade/scratch/mengyangz/archive/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.000-1999-01/ocn/hist/'
# da000_01 = xr.open_mfdataset(fpath + 'smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.000-1999-01.pop.h.*.nc')
# da000_01 = process(da000_01)


# fpath = '/glade/scratch/mengyangz/archive/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.016-1999-01/ocn/hist/'
# da016_01 = xr.open_mfdataset(fpath + 'smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.016-1999-01.pop.h.*.nc')
# da016_01 = process(da016_01)


fpath = '/glade/scratch/mengyangz/archive/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.036-1999-01/ocn/hist/'
da036_01 = xr.open_mfdataset(fpath + 'smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.036-1999-01.pop.h.*.nc')
da036_01 = process(da036_01)


# fpath = '/glade/scratch/mengyangz/archive/smyle-fosi.North_Pacific_basin.alk-forcing-North_Pacific_basin.105-1999-01/ocn/hist/'
# da105_01 = xr.open_mfdataset(fpath + 'smyle-fosi.North_Pacific_basin.alk-forcing-North_Pacific_basin.105-1999-01.pop.h.*.nc')
# da105_01 = process(da105_01)

# fpath = '/glade/scratch/mengyangz/archive/smyle-fosi.North_Pacific_basin.alk-forcing-North_Pacific_basin.155-1999-01/ocn/hist/'
# da155_01 = xr.open_mfdataset(fpath + 'smyle-fosi.North_Pacific_basin.alk-forcing-North_Pacific_basin.155-1999-01.pop.h.*.nc')
# da155_01 = process(da155_01)

# %%
# ALk_added063 = (da063_01.ALK_FLUX * da063_01.TAREA).sum(['nlat', 'nlon'])*1e-9*86400*31  # mol/month sum all months
# exc_dic063= excess_dic(da063_01)
# total_exc_alk063 = cal_added_ALk(da063_01)

ALk_added036 = (da036_01.ALK_FLUX * da036_01.TAREA).sum(['nlat', 'nlon'])*1e-9*86400*31  # mol/month sum all months
exc_dic036= excess_dic(da036_01)
total_exc_alk036 = cal_added_ALk(da036_01)

# %%
fig = plt.figure(figsize=(12,3))
ax = fig.add_subplot(131)
ax.plot(ALk_added036.time, ALk_added036.values, ':', label='Month-long')
ax.plot(ALk_added.time, ALk_added.values, '--', color='r', label='5 Year-long')
ax.set_title('ALK_FLUX')
ax.set_ylabel('ALK_FLUX (mol/month)')
ax.set_xlabel('Time')

ax1 = fig.add_subplot(132)
ax1.plot(exc_dic036.time, exc_dic036, ':', label='Month-long')
ax1.plot(exc_dic.time, exc_dic, '--', color='r', label='5 Year-long')

ax1.set_ylabel('DIC inventory (mol)')
ax1.set_xlabel('Time')
ax1.set_title('DIC inventory')

ax2 = fig.add_subplot(133)
ax2.plot(exc_dic036.time, exc_dic036/total_exc_alk036, ':', label='Month-long')
ax2.plot(exc_dic.time, exc_dic/total_exc_alk, '--',  color='r', label='5 Year-long')

ax2.set_ylabel('excess DIC (mol) / added ALk (mol)')
ax2.set_xlabel('Time')
ax2.set_title('OAE efficiency')


ax.set_xlim(da.time.values[0] - timedelta(days=30), da.time.values[-1] + timedelta(days=30))
ax1.set_xlim(da.time.values[0] - timedelta(days=30), da.time.values[-1] + timedelta(days=30))
ax2.set_xlim(da.time.values[0] - timedelta(days=30), da.time.values[-1] + timedelta(days=30))

ax.legend()
ax1.legend()
ax2.legend()

plt.subplots_adjust(wspace=0.3)


# plt.savefig('/glade/work/mengyangz/GVP/figures/check_000_ALK_DIC_eff.png', 
#             dpi=200, bbox_inches='tight')

# %%
x_data = np.array(range(15*12))
def exponential_tau(t, eta_max, ktau, gtau, htau):
    '''
    t: time
    eta_max: initial condition (this doubles as intrinsic "max" efficiency, ~0.81)
    ktau: e-folding time of gas exchange
    gtau: e-folding time of loss to the deep
    htau: e-folding time of gas exchange for the deep reservoir
    '''
    alpha = gtau/(ktau+gtau)
    tau_kg = 1.0/(1/ktau+1/gtau)
    return eta_max * (1 -  alpha*np.exp(-(1/ktau+1/gtau)*t)
                         - (1-alpha)*np.exp(-t/htau)
                         - (1-alpha)*(tau_kg/(htau - tau_kg))*(np.exp(-t/htau) - np.exp(-t/tau_kg))
                    )


def fit_params_tau(x_data, y_data, bounds=None, initial=None, pink=None, ping=None, pinh=None):
    '''Return fitted parameters'''
    # Perform the curve fitting
    if bounds is None:
        #bounds=[[ 0.849,  1.96,   0,       0],
        #        [ 0.851,  1.98,  2000,  10000]]
        bounds=[[ 0.80,  2,    0,       5],
                [ 0.88, 50 ,  2000,  10000]]
    if initial is None:
       initial = [(bounds[0][0]+bounds[1][0])/2,
                   np.clip(4,bounds[0][1],bounds[1][1]),
                   np.clip(25,bounds[0][2],bounds[1][2]),
                   np.clip(70,bounds[0][3],bounds[1][3])]
    if pink is not None:
      bounds[0][1] = pink
      bounds[1][1] = pink+0.01
      initial[1] = pink
    if ping is not None:
      bounds[0][2] = ping
      bounds[1][2] = ping+0.01
      initial[2] = ping
    if pinh is not None:
      bounds[0][3] = pinh
      bounds[1][3] = pinh+0.01
      initial[3] = pinh

    popt, pcov = curve_fit(exponential_tau, x_data, y_data, p0=initial,
                           method='trf', maxfev=10000, bounds=bounds)

    stdev = np.sqrt(np.diag(pcov))
    #print("%.2f %.1f %.1f %.1f"%tuple(stdev))
    return popt

# %%
def fit_to_curve_tau(s, show=False, onlydata=False, *args, **kwargs):
  x_data = np.array(range(15*12))  # time in months


### REPLACE y_data with the correct dataset ###
  y_data = (exc_dic_01/total_exc_01).values
  #y_data = (exc_dic[0:180]/total_exc_alk).values

  y_data = y_data[~np.isnan(y_data)]  # get rid of nans
  if  len(y_data)<=1: # but abort if there's no data
    return np.nan,np.nan,np.nan,np.nan
  eta_max, ktau, gtau, htau = fit_params_tau(x_data, y_data, *args, **kwargs)
  if show:
    if onlydata:
      plt.plot(x_data, y_data)
    else:
      plt.plot(x_data, y_data, c="black",ls="dashed", label=None)
      plt.plot(x_data, exponential_tau(x_data, eta_max, ktau, gtau, htau),
             label = r"%s: eta=%.2f t$_{gas}$=%.1fm t$_{loss}$=%.1fm,  t$_{slow}$=%.1fm"%(["Constrained","Free            "][s],eta_max, ktau, gtau, htau))

    plt.legend(loc='lower right')
  return eta_max, ktau, gtau, htau

# %%
[eta_max, ktau, gtau, htau] = fit_to_curve_tau(1,show=True)
#plt.plot(t,test1,'--r')
#plt.plot(t,test2,'--y')
#plt.plot(convolution/np.nansum(ALk_added_total),'y')
plt.ylabel('$\eta$')
plt.xlabel('Time in months')
plt.title('Month-long release and fitting')
#plt.plot([0, 190],[0.85,0.85])
plt.grid('on')
plt.xlim([0,190])
plt.ylim([.0,.9])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /glade/derecho/scratch/eyankovsky/tmp/ipykernel_30897/1886763522.py in <module>
# ----> 1 [eta_max, ktau, gtau, htau] = fit_to_curve_tau(1,show=True)
#       2 #plt.plot(t,test1,'--r')
#       3 #plt.plot(t,test2,'--y')
#       4 #plt.plot(convolution/np.nansum(ALk_added_total),'y')
#       5 plt.ylabel('$\eta$')
#
# /glade/derecho/scratch/eyankovsky/tmp/ipykernel_30897/1361560051.py in fit_to_curve_tau(s, show, onlydata, *args, **kwargs)
#       1 def fit_to_curve_tau(s, show=False, onlydata=False, *args, **kwargs):
# ----> 2   x_data = np.array(range(15*12))  # time in months
#       3
#       4
#       5 ### REPLACE y_data with the correct dataset ###
#
# NameError: name 'np' is not defined

# %%
t = np.array(range(15*12))
alpha = gtau/(ktau+gtau)
tau_kg = 1.0/(1/ktau+1/gtau)

test1 = eta_max * (1 -  alpha*np.exp(-(1/ktau+1/gtau)*t)
                  - (1-alpha)*np.exp(-t/htau)
                  - (1-alpha)*(tau_kg/(htau - tau_kg))*(np.exp(-t/htau) - np.exp(-t/tau_kg)))

# %%
ALk_added_total = (da.ALK_FLUX * da.TAREA).sum(['nlat', 'nlon'])*1e-9*86400*31  # mol/month 
ALk_added_total.plot()

convolution1 = np.convolve(ALk_added_total, test1)

# %%
x_data = np.array(range(15*12))  # time in months
y_data = (exc_dic[0:180]/total_exc_alk).values
y_data = y_data[~np.isnan(y_data)]  # get rid of nans

plt.plot(convolution1/np.nansum(ALk_added_total),'r',label='Convolution with IRF')
plt.plot(x_data, y_data,'k:',label='5 Year-long release')

#plt.plot(yearlongx,yearlongy,'b:',label='Year-long release')

plt.plot(x_data, (exc_dic036/total_exc_alk036),'k--',label='Month-long release')

plt.ylabel('$\eta$')
plt.xlabel('Time in months')
plt.title('5 Year-long release and IRF results')
#plt.plot([0, 190],[0.85,0.85])
plt.grid('on')
plt.xlim([0,175])
plt.ylim([.0,.9])
plt.legend(loc='lower right')

# %%
x_data = np.array(range(15*12))  # time in months
y_data = (exc_dic[0:180]/total_exc_alk).values
y_data = y_data[~np.isnan(y_data)]  # get rid of nans

plt.plot(x_data, y_data/(convolution1[0:180]/np.nansum(ALk_added_total)),'b',label='5 Year-long release/IRF prediction')
plt.plot(x_data, y_data/(exc_dic036/total_exc_alk036),'m',label='5 Year-long release/Month-long release')

#plt.plot(x_data, (exc_dic063/total_exc_alk063),'k--',label='Month-long release')

plt.ylabel('$\eta$ ratio')
plt.xlabel('Time in months')
plt.title('Ratios')
#plt.plot([0, 190],[0.85,0.85])
plt.grid('on')
plt.xlim([0,175])
#plt.ylim([.0,.9])
plt.legend(loc='lower right')
# Out:
# /glade/work/eyankovsky/conda-envs/mcdr/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """

# %%
convolution1.shape
# Out:
# (419,)
