# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import socket
from glob import glob

import oae_smyle
import config
import xarray as xr

this_notebook = 'run-cesm.ipynb'
assert 'cheyenne' in socket.gethostname(), (
    'this notebook must be run on cheyenne login node'
)

# %% [markdown]
# # Run CESM
# 1. Change **project number** in config.py

# %%
# forcing files
alk_forcing_spec = 'North_Atlantic_basin'
year_spec        = '5year'
forcing_files = sorted(
    glob(f'/glade/scratch/eyankovsky/oae-dor-global-efficiency/data/{alk_forcing_spec}_{year_spec}/alk-forcing-{alk_forcing_spec}.*.nc')
)
# forcing_files = sorted(
#     glob(f'/glade/scratch/eyankovsky/oae-dor-global-efficiency/data/Labrador_ensemble/alk-forcing-{alk_forcing_spec}.*.nc')
# )
run_only_index_list = [i for i in range(len(forcing_files))]
    
len(forcing_files)

#forcing_files
# Out:
# 5

# %%
ds = xr.open_dataset(forcing_files[0])

# %%
ds.alk_forcing.sum(['X', 'Y'])[0:].plot(marker='o')

# %%
forcing_files
# Out:
# ['/glade/scratch/eyankovsky/oae-dor-global-efficiency/data/North_Atlantic_basin_5year/alk-forcing-North_Atlantic_basin.017-5year.nc',
#  '/glade/scratch/eyankovsky/oae-dor-global-efficiency/data/North_Atlantic_basin_5year/alk-forcing-North_Atlantic_basin.022-5year.nc',
#  '/glade/scratch/eyankovsky/oae-dor-global-efficiency/data/North_Atlantic_basin_5year/alk-forcing-North_Atlantic_basin.051-5year.nc',
#  '/glade/scratch/eyankovsky/oae-dor-global-efficiency/data/North_Atlantic_basin_5year/alk-forcing-North_Atlantic_basin.053-5year.nc',
#  '/glade/scratch/eyankovsky/oae-dor-global-efficiency/data/North_Atlantic_basin_5year/alk-forcing-North_Atlantic_basin.072-5year.nc']

# %%
clobber = True

run_settings = dict(
    stop_n=10,                #10 years
    stop_option="nyear",
    job_queue="regular",
    wallclock="12:00:00",
    resubmit=1,              #2 would give 30 years of output
)

#run_only_index_list = [0, 16, 36, 63] # use this list to run only select indexes 
#run_only_index_list = [105, 155] # use this list to run only select indexes 
#run_only_index_list = [17, 22, 72, 51, 53] # use this list to run only select indexes 

for n, f in enumerate(forcing_files):

    #if n not in run_only_index_list:
    #    continue

    alk_forcing = os.path.basename(f).replace('.nc', '')

    case = f"smyle-fosi.{alk_forcing_spec}.{alk_forcing}"
    oae_smyle.create_clone(
        case, 
        alk_forcing_file=f, 
        submit=True, 
        clobber=clobber, 
        curtail_output=True,
        **run_settings
    )
# Out:
#  Successfully created new case smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.017-5year from clone case g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (307200000, -1)
# /glade/work/bachman/oae-dor-global-efficiency/cesm-cases/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.017-5year/env_mach_specific.xml already exists, delete to replace
# /glade/work/bachman/oae-dor-global-efficiency/cesm-cases/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.017-5year/env_mach_specific.xml already exists, delete to replace
# job is case.run USER_REQUESTED_WALLTIME None USER_REQUESTED_QUEUE regular WALLTIME_FORMAT %H:%M:%S
# Creating batch scripts
# Writing case.run script from input template /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/config/cesm/machines/template.case.run
# Creating file .case.run
# Writing case.st_archive script from input template /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/config/cesm/machines/template.st_archive
# Creating file case.st_archive
# If an old case build already exists, might want to run 'case.build --clean' before building
# You can now run './preview_run' to get more info on how your case will be run
# INFO: Running consistency check for /glade/u/home/eyankovsky/CWorthy/SourceMods-OAE/src.pop.curtail-output/diagnostics_latest.yaml
# INFO: Writing /glade/work/bachman/oae-dor-global-efficiency/cesm-cases/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.017-5year/SourceMods/src.pop/diagnostics_latest.json
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (307200000, -1)
# Machine/Decomp/Pes configuration has already been done ...skipping
# If an old case build already exists, might want to run 'case.build --clean' before building
# You can now run './preview_run' to get more info on how your case will be run
# checkpoint 1
# /glade/work/bachman/oae-dor-global-efficiency/cesm-cases/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.017-5year
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (307200000, -1)
# GET_REFCASE is false, the user is expected to stage the refcase to the run directory.
# Creating component namelists
#   2023-12-29 21:02:41 atm
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/datm/cime_config/buildnml
#   2023-12-29 21:02:42 lnd
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/slnd/cime_config/buildnml
#   2023-12-29 21:02:42 ice
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/cice//cime_config/buildnml
#      ...buildnml calling cice buildcpp to set build time options
#   2023-12-29 21:02:43 ocn
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/pop//cime_config/buildnml
#      ... buildnml: calling pop buildcpp to set build time options
#   2023-12-29 21:02:46 rof
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/drof/cime_config/buildnml
#   2023-12-29 21:02:46 glc
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sglc/cime_config/buildnml
#   2023-12-29 21:02:46 wav
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/ww3//cime_config/buildnml
#   2023-12-29 21:02:46 iac
#    Running /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/siac/cime_config/buildnml
#   2023-12-29 21:02:47 esp
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sesp/cime_config/buildnml
#   2023-12-29 21:02:47 cpl
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/drivers/mct/cime_config/buildnml
# checkpoint 2
# Submitting command to PBS using account P93300612:
#     ./case.build
#
# Requested custom PBS options:
#     -A P93300612
#
# Waiting for job 4486929.chadmin1.ib0.cheyenne.ucar.edu to start ...
#
#
# Building case in directory /glade/work/bachman/oae-dor-global-efficiency/cesm-cases/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.017-5year
# sharedlib_only is False
# model_only is False
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# Generating component namelists as part of build
# GET_REFCASE is false, the user is expected to stage the refcase to the run directory.
# Creating component namelists
#   2023-12-29 21:03:48 atm
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/datm/cime_config/buildnml
#   2023-12-29 21:03:48 lnd
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/slnd/cime_config/buildnml
#   2023-12-29 21:03:48 ice
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/cice//cime_config/buildnml
#      ...buildnml calling cice buildcpp to set build time options
#   2023-12-29 21:03:49 ocn
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/pop//cime_config/buildnml
#      ... buildnml: calling pop buildcpp to set build time options
#   2023-12-29 21:03:51 rof
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/drof/cime_config/buildnml
#   2023-12-29 21:03:51 glc
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sglc/cime_config/buildnml
#   2023-12-29 21:03:51 wav
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/ww3//cime_config/buildnml
#   2023-12-29 21:03:51 iac
#    Running /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/siac/cime_config/buildnml
#   2023-12-29 21:03:51 esp
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sesp/cime_config/buildnml
#   2023-12-29 21:03:51 cpl
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/drivers/mct/cime_config/buildnml
# Building gptl with output to file /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.017-5year/bld/gptl.bldlog.231229-210347
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/build_scripts/buildlib.gptl
# Building mct with output to file /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.017-5year/bld/mct.bldlog.231229-210347
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/build_scripts/buildlib.mct
# Building pio with output to file /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.017-5year/bld/pio.bldlog.231229-210347
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/build_scripts/buildlib.pio
# Component pio build complete with 2 warnings
# Building csm_share with output to file /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.017-5year/bld/csm_share.bldlog.231229-210347
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/build_scripts/buildlib.csm_share
# Component csm_share build complete with 20 warnings
#          - Building atm Library
# Building atm with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.017-5year/bld/atm.bldlog.231229-210347
#          - Building lnd Library
# Building lnd with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.017-5year/bld/lnd.bldlog.231229-210347
#          - Building ice Library
# Building ice with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.017-5year/bld/ice.bldlog.231229-210347
#          - Building ocn Library
# Building ocn with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.017-5year/bld/ocn.bldlog.231229-210347
#          - Building rof Library
# Building rof with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.017-5year/bld/rof.bldlog.231229-210347
#          - Building glc Library
# Building glc with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.017-5year/bld/glc.bldlog.231229-210347
#          - Building wav Library
# Building wav with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.017-5year/bld/wav.bldlog.231229-210347
#          - Building iac Library
# Building iac with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.017-5year/bld/iac.bldlog.231229-210347
#          - Building esp Library
# Building esp with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.017-5year/bld/esp.bldlog.231229-210347
# sesp built in 1.894358 seconds
# sglc built in 1.935341 seconds
# slnd built in 1.979502 seconds
# siac built in 1.987839 seconds
# drof built in 4.002490 seconds
# datm built in 6.215852 seconds
# ww built in 33.719743 seconds
# Component ice build complete with 1 warnings
# cice built in 76.673609 seconds
# Component ocn build complete with 13 warnings
# pop built in 438.392166 seconds
# Building cesm from /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/drivers/mct/cime_config/buildexe with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.017-5year/bld/cesm.bldlog.231229-210347
# Time spent not building: 5.331739 sec
# Time spent building: 741.145412 sec
# MODEL BUILD HAS FINISHED SUCCESSFULLY
# env_batch.xml appears to have changed, regenerating batch scripts
# manual edits to these file will be lost!
# Creating batch scripts
# Writing case.run script from input template /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/config/cesm/machines/template.case.run
# Creating file .case.run
# Writing case.st_archive script from input template /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/config/cesm/machines/template.st_archive
# Creating file case.st_archive
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (307200000, -1)
# GET_REFCASE is false, the user is expected to stage the refcase to the run directory.
# Creating component namelists
#   2023-12-29 21:16:32 atm
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/datm/cime_config/buildnml
#   2023-12-29 21:16:33 lnd
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/slnd/cime_config/buildnml
#   2023-12-29 21:16:33 ice
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/cice//cime_config/buildnml
#   2023-12-29 21:16:33 ocn
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/pop//cime_config/buildnml
#   2023-12-29 21:16:34 rof
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/drof/cime_config/buildnml
#   2023-12-29 21:16:35 glc
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sglc/cime_config/buildnml
#   2023-12-29 21:16:35 wav
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/ww3//cime_config/buildnml
#   2023-12-29 21:16:35 iac
#    Running /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/siac/cime_config/buildnml
#   2023-12-29 21:16:35 esp
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sesp/cime_config/buildnml
#   2023-12-29 21:16:35 cpl
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/drivers/mct/cime_config/buildnml
# Checking that inputdata is available as part of case submission
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# Loading input file list: 'Buildconf/cpl.input_data_list'
# Loading input file list: 'Buildconf/pop.input_data_list'
# Loading input file list: 'Buildconf/ww3.input_data_list'
# Loading input file list: 'Buildconf/datm.input_data_list'
# Loading input file list: 'Buildconf/drof.input_data_list'
# Loading input file list: 'Buildconf/cice.input_data_list'
# GET_REFCASE is false, the user is expected to stage the refcase to the run directory.
# GET_REFCASE is false, the user is expected to stage the refcase to the run directory.
# Creating component namelists
#   2023-12-29 21:16:37 atm
#   2023-12-29 21:16:37 lnd
#   2023-12-29 21:16:37 ice
#   2023-12-29 21:16:37 ocn
#   2023-12-29 21:16:37 rof
#   2023-12-29 21:16:37 glc
#   2023-12-29 21:16:37 wav
#   2023-12-29 21:16:37 iac
#   2023-12-29 21:16:37 esp
#   2023-12-29 21:16:37 cpl
# Check case OK
# Submitting job script qsub -q regular -l walltime=12:00:00 -A P93300612 -v ARGS_FOR_SCRIPT='--resubmit' .case.run
# submit_jobs case.run
# Submit job case.run
# Submit job case.st_archive
# Submitted job id is 4486964.chadmin1.ib0.cheyenne.ucar.edu
# Submitting job script qsub -q regular -l walltime=12:00:00 -A P93300612  -W depend=afterok:4486964.chadmin1.ib0.cheyenne.ucar.edu -v ARGS_FOR_SCRIPT='--resubmit' case.st_archive
# Submitted job id is 4486966.chadmin1.ib0.cheyenne.ucar.edu
# Submitted job case.run with id 4486964.chadmin1.ib0.cheyenne.ucar.edu
# Submitted job case.st_archive with id 4486966.chadmin1.ib0.cheyenne.ucar.edu
#  Successfully created new case smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.022-5year from clone case g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (307200000, -1)
# job is case.run USER_REQUESTED_WALLTIME None USER_REQUESTED_QUEUE regular WALLTIME_FORMAT %H:%M:%S
# Creating batch scripts
# Writing case.run script from input template /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/config/cesm/machines/template.case.run
# /glade/work/bachman/oae-dor-global-efficiency/cesm-cases/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.022-5year/env_mach_specific.xml already exists, delete to replace
# /glade/work/bachman/oae-dor-global-efficiency/cesm-cases/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.022-5year/env_mach_specific.xml already exists, delete to replace
# Creating file .case.run
# Writing case.st_archive script from input template /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/config/cesm/machines/template.st_archive
# Creating file case.st_archive
# If an old case build already exists, might want to run 'case.build --clean' before building
# You can now run './preview_run' to get more info on how your case will be run
# INFO: Running consistency check for /glade/u/home/eyankovsky/CWorthy/SourceMods-OAE/src.pop.curtail-output/diagnostics_latest.yaml
# INFO: Writing /glade/work/bachman/oae-dor-global-efficiency/cesm-cases/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.022-5year/SourceMods/src.pop/diagnostics_latest.json
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (307200000, -1)
# Machine/Decomp/Pes configuration has already been done ...skipping
# If an old case build already exists, might want to run 'case.build --clean' before building
# You can now run './preview_run' to get more info on how your case will be run
# checkpoint 1
# /glade/work/bachman/oae-dor-global-efficiency/cesm-cases/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.022-5year
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (307200000, -1)
# GET_REFCASE is false, the user is expected to stage the refcase to the run directory.
# Creating component namelists
#   2023-12-29 21:16:51 atm
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/datm/cime_config/buildnml
#   2023-12-29 21:17:04 lnd
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/slnd/cime_config/buildnml
#   2023-12-29 21:17:04 ice
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/cice//cime_config/buildnml
#      ...buildnml calling cice buildcpp to set build time options
#   2023-12-29 21:17:04 ocn
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/pop//cime_config/buildnml
#      ... buildnml: calling pop buildcpp to set build time options
#   2023-12-29 21:17:07 rof
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/drof/cime_config/buildnml
#   2023-12-29 21:17:07 glc
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sglc/cime_config/buildnml
#   2023-12-29 21:17:07 wav
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/ww3//cime_config/buildnml
#   2023-12-29 21:17:08 iac
#    Running /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/siac/cime_config/buildnml
#   2023-12-29 21:17:08 esp
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sesp/cime_config/buildnml
#   2023-12-29 21:17:08 cpl
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/drivers/mct/cime_config/buildnml
# checkpoint 2
# Submitting command to PBS using account P93300612:
#     ./case.build
#
# Requested custom PBS options:
#     -A P93300612
#
# Waiting for job 4486971.chadmin1.ib0.cheyenne.ucar.edu to start ...
#
#
# Building case in directory /glade/work/bachman/oae-dor-global-efficiency/cesm-cases/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.022-5year
# sharedlib_only is False
# model_only is False
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# Generating component namelists as part of build
# GET_REFCASE is false, the user is expected to stage the refcase to the run directory.
# Creating component namelists
#   2023-12-29 21:18:03 atm
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/datm/cime_config/buildnml
#   2023-12-29 21:18:56 lnd
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/slnd/cime_config/buildnml
#   2023-12-29 21:18:56 ice
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/cice//cime_config/buildnml
#      ...buildnml calling cice buildcpp to set build time options
#   2023-12-29 21:18:56 ocn
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/pop//cime_config/buildnml
#      ... buildnml: calling pop buildcpp to set build time options
#   2023-12-29 21:18:58 rof
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/drof/cime_config/buildnml
#   2023-12-29 21:18:59 glc
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sglc/cime_config/buildnml
#   2023-12-29 21:18:59 wav
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/ww3//cime_config/buildnml
#   2023-12-29 21:18:59 iac
#    Running /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/siac/cime_config/buildnml
#   2023-12-29 21:18:59 esp
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sesp/cime_config/buildnml
#   2023-12-29 21:18:59 cpl
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/drivers/mct/cime_config/buildnml
# Building gptl with output to file /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.022-5year/bld/gptl.bldlog.231229-211802
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/build_scripts/buildlib.gptl
# Building mct with output to file /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.022-5year/bld/mct.bldlog.231229-211802
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/build_scripts/buildlib.mct
# Building pio with output to file /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.022-5year/bld/pio.bldlog.231229-211802
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/build_scripts/buildlib.pio
# Component pio build complete with 2 warnings
# Building csm_share with output to file /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.022-5year/bld/csm_share.bldlog.231229-211802
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/build_scripts/buildlib.csm_share
# Component csm_share build complete with 20 warnings
#          - Building atm Library
# Building atm with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.022-5year/bld/atm.bldlog.231229-211802
#          - Building lnd Library
# Building lnd with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.022-5year/bld/lnd.bldlog.231229-211802
#          - Building ice Library
# Building ice with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.022-5year/bld/ice.bldlog.231229-211802
#          - Building ocn Library
# Building ocn with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.022-5year/bld/ocn.bldlog.231229-211802
#          - Building rof Library
# Building rof with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.022-5year/bld/rof.bldlog.231229-211802
#          - Building glc Library
# Building glc with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.022-5year/bld/glc.bldlog.231229-211802
#          - Building wav Library
# Building wav with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.022-5year/bld/wav.bldlog.231229-211802
#          - Building iac Library
# Building iac with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.022-5year/bld/iac.bldlog.231229-211802
#          - Building esp Library
# Building esp with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.022-5year/bld/esp.bldlog.231229-211802
# slnd built in 2.356014 seconds
# sesp built in 2.265799 seconds
# sglc built in 2.412951 seconds
# siac built in 2.566551 seconds
# drof built in 5.087541 seconds
# datm built in 7.446609 seconds
# ww built in 33.265354 seconds
# Component ice build complete with 1 warnings
# cice built in 75.934529 seconds
# Component ocn build complete with 13 warnings
# pop built in 423.705659 seconds
# Building cesm from /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/drivers/mct/cime_config/buildexe with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.022-5year/bld/cesm.bldlog.231229-211802
# Time spent not building: 58.272992 sec
# Time spent building: 782.512900 sec
# MODEL BUILD HAS FINISHED SUCCESSFULLY
# env_batch.xml appears to have changed, regenerating batch scripts
# manual edits to these file will be lost!
# Creating batch scripts
# Writing case.run script from input template /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/config/cesm/machines/template.case.run
# Creating file .case.run
# Writing case.st_archive script from input template /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/config/cesm/machines/template.st_archive
# Creating file case.st_archive
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (307200000, -1)
# GET_REFCASE is false, the user is expected to stage the refcase to the run directory.
# Creating component namelists
#   2023-12-29 21:32:22 atm
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/datm/cime_config/buildnml
#   2023-12-29 21:32:23 lnd
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/slnd/cime_config/buildnml
#   2023-12-29 21:32:23 ice
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/cice//cime_config/buildnml
#   2023-12-29 21:32:23 ocn
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/pop//cime_config/buildnml
#   2023-12-29 21:32:25 rof
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/drof/cime_config/buildnml
#   2023-12-29 21:32:25 glc
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sglc/cime_config/buildnml
#   2023-12-29 21:32:25 wav
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/ww3//cime_config/buildnml
#   2023-12-29 21:32:26 iac
#    Running /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/siac/cime_config/buildnml
#   2023-12-29 21:32:26 esp
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sesp/cime_config/buildnml
#   2023-12-29 21:32:26 cpl
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/drivers/mct/cime_config/buildnml
# Checking that inputdata is available as part of case submission
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# Loading input file list: 'Buildconf/cpl.input_data_list'
# Loading input file list: 'Buildconf/pop.input_data_list'
# Loading input file list: 'Buildconf/ww3.input_data_list'
# Loading input file list: 'Buildconf/datm.input_data_list'
# Loading input file list: 'Buildconf/drof.input_data_list'
# Loading input file list: 'Buildconf/cice.input_data_list'
# GET_REFCASE is false, the user is expected to stage the refcase to the run directory.
# GET_REFCASE is false, the user is expected to stage the refcase to the run directory.
# Creating component namelists
#   2023-12-29 21:32:28 atm
#   2023-12-29 21:32:28 lnd
#   2023-12-29 21:32:28 ice
#   2023-12-29 21:32:28 ocn
#   2023-12-29 21:32:28 rof
#   2023-12-29 21:32:28 glc
#   2023-12-29 21:32:28 wav
#   2023-12-29 21:32:28 iac
#   2023-12-29 21:32:28 esp
#   2023-12-29 21:32:28 cpl
# Check case OK
# Submitting job script qsub -q regular -l walltime=12:00:00 -A P93300612 -v ARGS_FOR_SCRIPT='--resubmit' .case.run
# Submitted job id is 4486997.chadmin1.ib0.cheyenne.ucar.edu
# Submitting job script qsub -q regular -l walltime=12:00:00 -A P93300612  -W depend=afterok:4486997.chadmin1.ib0.cheyenne.ucar.edu -v ARGS_FOR_SCRIPT='--resubmit' case.st_archive
# submit_jobs case.run
# Submit job case.run
# Submit job case.st_archive
# Submitted job id is 4486998.chadmin1.ib0.cheyenne.ucar.edu
# Submitted job case.run with id 4486997.chadmin1.ib0.cheyenne.ucar.edu
# Submitted job case.st_archive with id 4486998.chadmin1.ib0.cheyenne.ucar.edu
#  Successfully created new case smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.051-5year from clone case g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (307200000, -1)
# /glade/work/bachman/oae-dor-global-efficiency/cesm-cases/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.051-5year/env_mach_specific.xml already exists, delete to replace
# /glade/work/bachman/oae-dor-global-efficiency/cesm-cases/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.051-5year/env_mach_specific.xml already exists, delete to replace
# job is case.run USER_REQUESTED_WALLTIME None USER_REQUESTED_QUEUE regular WALLTIME_FORMAT %H:%M:%S
# Creating batch scripts
# Writing case.run script from input template /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/config/cesm/machines/template.case.run
# Creating file .case.run
# Writing case.st_archive script from input template /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/config/cesm/machines/template.st_archive
# Creating file case.st_archive
# If an old case build already exists, might want to run 'case.build --clean' before building
# You can now run './preview_run' to get more info on how your case will be run
# INFO: Running consistency check for /glade/u/home/eyankovsky/CWorthy/SourceMods-OAE/src.pop.curtail-output/diagnostics_latest.yaml
# INFO: Writing /glade/work/bachman/oae-dor-global-efficiency/cesm-cases/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.051-5year/SourceMods/src.pop/diagnostics_latest.json
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (307200000, -1)
# Machine/Decomp/Pes configuration has already been done ...skipping
# If an old case build already exists, might want to run 'case.build --clean' before building
# You can now run './preview_run' to get more info on how your case will be run
# checkpoint 1
# /glade/work/bachman/oae-dor-global-efficiency/cesm-cases/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.051-5year
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (307200000, -1)
# GET_REFCASE is false, the user is expected to stage the refcase to the run directory.
# Creating component namelists
#   2023-12-29 21:32:43 atm
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/datm/cime_config/buildnml
#   2023-12-29 21:32:44 lnd
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/slnd/cime_config/buildnml
#   2023-12-29 21:32:44 ice
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/cice//cime_config/buildnml
#      ...buildnml calling cice buildcpp to set build time options
#   2023-12-29 21:32:44 ocn
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/pop//cime_config/buildnml
#      ... buildnml: calling pop buildcpp to set build time options
#   2023-12-29 21:32:45 rof
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/drof/cime_config/buildnml
#   2023-12-29 21:32:45 glc
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sglc/cime_config/buildnml
#   2023-12-29 21:32:45 wav
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/ww3//cime_config/buildnml
#   2023-12-29 21:32:45 iac
#    Running /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/siac/cime_config/buildnml
#   2023-12-29 21:32:45 esp
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sesp/cime_config/buildnml
#   2023-12-29 21:32:45 cpl
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/drivers/mct/cime_config/buildnml
# checkpoint 2
# Submitting command to PBS using account P93300612:
#     ./case.build
#
# Requested custom PBS options:
#     -A P93300612
#
# Waiting for job 4486999.chadmin1.ib0.cheyenne.ucar.edu to start ...
#
#
# Building case in directory /glade/work/bachman/oae-dor-global-efficiency/cesm-cases/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.051-5year
# sharedlib_only is False
# model_only is False
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# Generating component namelists as part of build
# GET_REFCASE is false, the user is expected to stage the refcase to the run directory.
# Creating component namelists
#   2023-12-29 21:33:32 atm
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/datm/cime_config/buildnml
#   2023-12-29 21:33:32 lnd
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/slnd/cime_config/buildnml
#   2023-12-29 21:33:32 ice
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/cice//cime_config/buildnml
#      ...buildnml calling cice buildcpp to set build time options
#   2023-12-29 21:33:33 ocn
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/pop//cime_config/buildnml
#      ... buildnml: calling pop buildcpp to set build time options
#   2023-12-29 21:33:35 rof
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/drof/cime_config/buildnml
#   2023-12-29 21:33:35 glc
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sglc/cime_config/buildnml
#   2023-12-29 21:33:35 wav
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/ww3//cime_config/buildnml
#   2023-12-29 21:33:36 iac
#    Running /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/siac/cime_config/buildnml
#   2023-12-29 21:33:36 esp
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sesp/cime_config/buildnml
#   2023-12-29 21:33:36 cpl
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/drivers/mct/cime_config/buildnml
# Building gptl with output to file /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.051-5year/bld/gptl.bldlog.231229-213331
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/build_scripts/buildlib.gptl
# Building mct with output to file /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.051-5year/bld/mct.bldlog.231229-213331
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/build_scripts/buildlib.mct
# Building pio with output to file /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.051-5year/bld/pio.bldlog.231229-213331
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/build_scripts/buildlib.pio
# Component pio build complete with 2 warnings
# Building csm_share with output to file /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.051-5year/bld/csm_share.bldlog.231229-213331
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/build_scripts/buildlib.csm_share
# Component csm_share build complete with 20 warnings
#          - Building atm Library
# Building atm with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.051-5year/bld/atm.bldlog.231229-213331
#          - Building lnd Library
# Building lnd with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.051-5year/bld/lnd.bldlog.231229-213331
#          - Building ice Library
# Building ice with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.051-5year/bld/ice.bldlog.231229-213331
#          - Building ocn Library
# Building ocn with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.051-5year/bld/ocn.bldlog.231229-213331
#          - Building rof Library
# Building rof with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.051-5year/bld/rof.bldlog.231229-213331
#          - Building glc Library
# Building glc with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.051-5year/bld/glc.bldlog.231229-213331
#          - Building wav Library
# Building wav with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.051-5year/bld/wav.bldlog.231229-213331
#          - Building iac Library
# Building iac with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.051-5year/bld/iac.bldlog.231229-213331
#          - Building esp Library
# Building esp with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.051-5year/bld/esp.bldlog.231229-213331
# slnd built in 1.754411 seconds
# siac built in 1.820857 seconds
# sglc built in 1.882497 seconds
# sesp built in 1.877634 seconds
# drof built in 4.093769 seconds
# datm built in 5.720227 seconds
# ww built in 33.085944 seconds
# Component ice build complete with 1 warnings
# cice built in 76.305749 seconds
# Component ocn build complete with 13 warnings
# pop built in 432.563645 seconds
# Building cesm from /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/drivers/mct/cime_config/buildexe with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.051-5year/bld/cesm.bldlog.231229-213331
# Time spent not building: 6.065266 sec
# Time spent building: 698.343496 sec
# MODEL BUILD HAS FINISHED SUCCESSFULLY
# env_batch.xml appears to have changed, regenerating batch scripts
# manual edits to these file will be lost!
# Creating batch scripts
# Writing case.run script from input template /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/config/cesm/machines/template.case.run
# Creating file .case.run
# Writing case.st_archive script from input template /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/config/cesm/machines/template.st_archive
# Creating file case.st_archive
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (307200000, -1)
# GET_REFCASE is false, the user is expected to stage the refcase to the run directory.
# Creating component namelists
#   2023-12-29 21:45:35 atm
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/datm/cime_config/buildnml
#   2023-12-29 21:45:37 lnd
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/slnd/cime_config/buildnml
#   2023-12-29 21:45:37 ice
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/cice//cime_config/buildnml
#   2023-12-29 21:45:37 ocn
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/pop//cime_config/buildnml
#   2023-12-29 21:45:40 rof
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/drof/cime_config/buildnml
#   2023-12-29 21:45:40 glc
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sglc/cime_config/buildnml
#   2023-12-29 21:45:40 wav
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/ww3//cime_config/buildnml
#   2023-12-29 21:45:40 iac
#    Running /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/siac/cime_config/buildnml
#   2023-12-29 21:45:40 esp
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sesp/cime_config/buildnml
#   2023-12-29 21:45:40 cpl
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/drivers/mct/cime_config/buildnml
# Checking that inputdata is available as part of case submission
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# Loading input file list: 'Buildconf/cpl.input_data_list'
# Loading input file list: 'Buildconf/pop.input_data_list'
# Loading input file list: 'Buildconf/ww3.input_data_list'
# Loading input file list: 'Buildconf/datm.input_data_list'
# Loading input file list: 'Buildconf/drof.input_data_list'
# Loading input file list: 'Buildconf/cice.input_data_list'
# GET_REFCASE is false, the user is expected to stage the refcase to the run directory.
# GET_REFCASE is false, the user is expected to stage the refcase to the run directory.
# Creating component namelists
#   2023-12-29 21:45:42 atm
#   2023-12-29 21:45:42 lnd
#   2023-12-29 21:45:42 ice
#   2023-12-29 21:45:42 ocn
#   2023-12-29 21:45:42 rof
#   2023-12-29 21:45:42 glc
#   2023-12-29 21:45:42 wav
#   2023-12-29 21:45:42 iac
#   2023-12-29 21:45:42 esp
#   2023-12-29 21:45:42 cpl
# Check case OK
# Submitting job script qsub -q regular -l walltime=12:00:00 -A P93300612 -v ARGS_FOR_SCRIPT='--resubmit' .case.run
# submit_jobs case.run
# Submit job case.run
# Submitted job id is 4487012.chadmin1.ib0.cheyenne.ucar.edu
# Submitting job script qsub -q regular -l walltime=12:00:00 -A P93300612  -W depend=afterok:4487012.chadmin1.ib0.cheyenne.ucar.edu -v ARGS_FOR_SCRIPT='--resubmit' case.st_archive
# Submit job case.st_archive
# Submitted job id is 4487013.chadmin1.ib0.cheyenne.ucar.edu
# Submitted job case.run with id 4487012.chadmin1.ib0.cheyenne.ucar.edu
# Submitted job case.st_archive with id 4487013.chadmin1.ib0.cheyenne.ucar.edu
#  Successfully created new case smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.053-5year from clone case g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (307200000, -1)
# /glade/work/bachman/oae-dor-global-efficiency/cesm-cases/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.053-5year/env_mach_specific.xml already exists, delete to replace
# /glade/work/bachman/oae-dor-global-efficiency/cesm-cases/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.053-5year/env_mach_specific.xml already exists, delete to replace
# job is case.run USER_REQUESTED_WALLTIME None USER_REQUESTED_QUEUE regular WALLTIME_FORMAT %H:%M:%S
# Creating batch scripts
# Writing case.run script from input template /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/config/cesm/machines/template.case.run
# Creating file .case.run
# Writing case.st_archive script from input template /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/config/cesm/machines/template.st_archive
# Creating file case.st_archive
# If an old case build already exists, might want to run 'case.build --clean' before building
# You can now run './preview_run' to get more info on how your case will be run
# INFO: Running consistency check for /glade/u/home/eyankovsky/CWorthy/SourceMods-OAE/src.pop.curtail-output/diagnostics_latest.yaml
# INFO: Writing /glade/work/bachman/oae-dor-global-efficiency/cesm-cases/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.053-5year/SourceMods/src.pop/diagnostics_latest.json
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (307200000, -1)
# Machine/Decomp/Pes configuration has already been done ...skipping
# If an old case build already exists, might want to run 'case.build --clean' before building
# You can now run './preview_run' to get more info on how your case will be run
# checkpoint 1
# /glade/work/bachman/oae-dor-global-efficiency/cesm-cases/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.053-5year
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (307200000, -1)
# GET_REFCASE is false, the user is expected to stage the refcase to the run directory.
# Creating component namelists
#   2023-12-29 21:45:58 atm
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/datm/cime_config/buildnml
#   2023-12-29 21:45:58 lnd
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/slnd/cime_config/buildnml
#   2023-12-29 21:45:58 ice
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/cice//cime_config/buildnml
#      ...buildnml calling cice buildcpp to set build time options
#   2023-12-29 21:45:58 ocn
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/pop//cime_config/buildnml
#      ... buildnml: calling pop buildcpp to set build time options
#   2023-12-29 21:46:00 rof
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/drof/cime_config/buildnml
#   2023-12-29 21:46:00 glc
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sglc/cime_config/buildnml
#   2023-12-29 21:46:00 wav
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/ww3//cime_config/buildnml
#   2023-12-29 21:46:00 iac
#    Running /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/siac/cime_config/buildnml
#   2023-12-29 21:46:00 esp
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sesp/cime_config/buildnml
#   2023-12-29 21:46:00 cpl
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/drivers/mct/cime_config/buildnml
# checkpoint 2
# Submitting command to PBS using account P93300612:
#     ./case.build
#
# Requested custom PBS options:
#     -A P93300612
#
# Waiting for job 4487014.chadmin1.ib0.cheyenne.ucar.edu to start ...
#
#
# Building case in directory /glade/work/bachman/oae-dor-global-efficiency/cesm-cases/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.053-5year
# sharedlib_only is False
# model_only is False
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# Generating component namelists as part of build
# GET_REFCASE is false, the user is expected to stage the refcase to the run directory.
# Creating component namelists
#   2023-12-29 21:46:44 atm
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/datm/cime_config/buildnml
#   2023-12-29 21:46:44 lnd
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/slnd/cime_config/buildnml
#   2023-12-29 21:46:44 ice
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/cice//cime_config/buildnml
#      ...buildnml calling cice buildcpp to set build time options
#   2023-12-29 21:46:44 ocn
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/pop//cime_config/buildnml
#      ... buildnml: calling pop buildcpp to set build time options
#   2023-12-29 21:46:46 rof
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/drof/cime_config/buildnml
#   2023-12-29 21:46:46 glc
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sglc/cime_config/buildnml
#   2023-12-29 21:46:46 wav
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/ww3//cime_config/buildnml
#   2023-12-29 21:46:46 iac
#    Running /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/siac/cime_config/buildnml
#   2023-12-29 21:46:46 esp
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sesp/cime_config/buildnml
#   2023-12-29 21:46:46 cpl
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/drivers/mct/cime_config/buildnml
# Building gptl with output to file /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.053-5year/bld/gptl.bldlog.231229-214643
# ...
#   2023-12-29 21:58:36 iac
#    Running /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/siac/cime_config/buildnml
#   2023-12-29 21:58:36 esp
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sesp/cime_config/buildnml
#   2023-12-29 21:58:36 cpl
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/drivers/mct/cime_config/buildnml
# Checking that inputdata is available as part of case submission
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# Loading input file list: 'Buildconf/cpl.input_data_list'
# Loading input file list: 'Buildconf/pop.input_data_list'
# Loading input file list: 'Buildconf/ww3.input_data_list'
# Loading input file list: 'Buildconf/datm.input_data_list'
# Loading input file list: 'Buildconf/drof.input_data_list'
# Loading input file list: 'Buildconf/cice.input_data_list'
# GET_REFCASE is false, the user is expected to stage the refcase to the run directory.
# GET_REFCASE is false, the user is expected to stage the refcase to the run directory.
# Creating component namelists
#   2023-12-29 21:58:41 atm
#   2023-12-29 21:58:41 lnd
#   2023-12-29 21:58:41 ice
#   2023-12-29 21:58:41 ocn
#   2023-12-29 21:58:41 rof
#   2023-12-29 21:58:41 glc
#   2023-12-29 21:58:41 wav
#   2023-12-29 21:58:41 iac
#   2023-12-29 21:58:41 esp
#   2023-12-29 21:58:41 cpl
# Check case OK
# Submitting job script qsub -q regular -l walltime=12:00:00 -A P93300612 -v ARGS_FOR_SCRIPT='--resubmit' .case.run
# submit_jobs case.run
# Submit job case.run
# Submit job case.st_archive
# Submitted job id is 4487024.chadmin1.ib0.cheyenne.ucar.edu
# Submitting job script qsub -q regular -l walltime=12:00:00 -A P93300612  -W depend=afterok:4487024.chadmin1.ib0.cheyenne.ucar.edu -v ARGS_FOR_SCRIPT='--resubmit' case.st_archive
# Submitted job id is 4487025.chadmin1.ib0.cheyenne.ucar.edu
# Submitted job case.run with id 4487024.chadmin1.ib0.cheyenne.ucar.edu
# Submitted job case.st_archive with id 4487025.chadmin1.ib0.cheyenne.ucar.edu
#  Successfully created new case smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.072-5year from clone case g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (307200000, -1)
# /glade/work/bachman/oae-dor-global-efficiency/cesm-cases/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.072-5year/env_mach_specific.xml already exists, delete to replace
# /glade/work/bachman/oae-dor-global-efficiency/cesm-cases/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.072-5year/env_mach_specific.xml already exists, delete to replace
# job is case.run USER_REQUESTED_WALLTIME None USER_REQUESTED_QUEUE regular WALLTIME_FORMAT %H:%M:%S
# Creating batch scripts
# Writing case.run script from input template /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/config/cesm/machines/template.case.run
# Creating file .case.run
# Writing case.st_archive script from input template /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/config/cesm/machines/template.st_archive
# Creating file case.st_archive
# If an old case build already exists, might want to run 'case.build --clean' before building
# You can now run './preview_run' to get more info on how your case will be run
# INFO: Running consistency check for /glade/u/home/eyankovsky/CWorthy/SourceMods-OAE/src.pop.curtail-output/diagnostics_latest.yaml
# INFO: Writing /glade/work/bachman/oae-dor-global-efficiency/cesm-cases/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.072-5year/SourceMods/src.pop/diagnostics_latest.json
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (307200000, -1)
# Machine/Decomp/Pes configuration has already been done ...skipping
# If an old case build already exists, might want to run 'case.build --clean' before building
# You can now run './preview_run' to get more info on how your case will be run
# checkpoint 1
# /glade/work/bachman/oae-dor-global-efficiency/cesm-cases/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.072-5year
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (307200000, -1)
# GET_REFCASE is false, the user is expected to stage the refcase to the run directory.
# Creating component namelists
#   2023-12-29 22:01:53 atm
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/datm/cime_config/buildnml
#   2023-12-29 22:01:54 lnd
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/slnd/cime_config/buildnml
#   2023-12-29 22:01:54 ice
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/cice//cime_config/buildnml
#      ...buildnml calling cice buildcpp to set build time options
#   2023-12-29 22:01:54 ocn
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/pop//cime_config/buildnml
#      ... buildnml: calling pop buildcpp to set build time options
#   2023-12-29 22:01:55 rof
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/drof/cime_config/buildnml
#   2023-12-29 22:01:55 glc
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sglc/cime_config/buildnml
#   2023-12-29 22:01:55 wav
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/ww3//cime_config/buildnml
#   2023-12-29 22:01:56 iac
#    Running /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/siac/cime_config/buildnml
#   2023-12-29 22:01:56 esp
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sesp/cime_config/buildnml
#   2023-12-29 22:01:56 cpl
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/drivers/mct/cime_config/buildnml
# checkpoint 2
# Submitting command to PBS using account P93300612:
#     ./case.build
#
# Requested custom PBS options:
#     -A P93300612
#
# Waiting for job 4487031.chadmin1.ib0.cheyenne.ucar.edu to start ...
#
#
# Building case in directory /glade/work/bachman/oae-dor-global-efficiency/cesm-cases/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.072-5year
# sharedlib_only is False
# model_only is False
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# Generating component namelists as part of build
# GET_REFCASE is false, the user is expected to stage the refcase to the run directory.
# Creating component namelists
#   2023-12-29 22:02:44 atm
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/datm/cime_config/buildnml
#   2023-12-29 22:04:34 lnd
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/slnd/cime_config/buildnml
#   2023-12-29 22:04:34 ice
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/cice//cime_config/buildnml
#      ...buildnml calling cice buildcpp to set build time options
#   2023-12-29 22:04:35 ocn
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/pop//cime_config/buildnml
#      ... buildnml: calling pop buildcpp to set build time options
#   2023-12-29 22:04:38 rof
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/drof/cime_config/buildnml
#   2023-12-29 22:04:41 glc
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sglc/cime_config/buildnml
#   2023-12-29 22:04:41 wav
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/ww3//cime_config/buildnml
#   2023-12-29 22:04:41 iac
#    Running /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/siac/cime_config/buildnml
#   2023-12-29 22:04:41 esp
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sesp/cime_config/buildnml
#   2023-12-29 22:04:41 cpl
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/drivers/mct/cime_config/buildnml
# Building gptl with output to file /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.072-5year/bld/gptl.bldlog.231229-220243
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/build_scripts/buildlib.gptl
# Building mct with output to file /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.072-5year/bld/mct.bldlog.231229-220243
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/build_scripts/buildlib.mct
# Building pio with output to file /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.072-5year/bld/pio.bldlog.231229-220243
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/build_scripts/buildlib.pio
# Component pio build complete with 2 warnings
# Building csm_share with output to file /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.072-5year/bld/csm_share.bldlog.231229-220243
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/build_scripts/buildlib.csm_share
# Component csm_share build complete with 20 warnings
#          - Building atm Library
# Building atm with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.072-5year/bld/atm.bldlog.231229-220243
#          - Building lnd Library
# Building lnd with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.072-5year/bld/lnd.bldlog.231229-220243
#          - Building ice Library
# Building ice with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.072-5year/bld/ice.bldlog.231229-220243
#          - Building ocn Library
# Building ocn with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.072-5year/bld/ocn.bldlog.231229-220243
#          - Building rof Library
# Building rof with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.072-5year/bld/rof.bldlog.231229-220243
#          - Building glc Library
# Building glc with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.072-5year/bld/glc.bldlog.231229-220243
#          - Building wav Library
# Building wav with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.072-5year/bld/wav.bldlog.231229-220243
#          - Building iac Library
# Building iac with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.072-5year/bld/iac.bldlog.231229-220243
#          - Building esp Library
# Building esp with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.072-5year/bld/esp.bldlog.231229-220243
# slnd built in 2.505142 seconds
# sglc built in 2.686172 seconds
# sesp built in 2.695677 seconds
# siac built in 3.242891 seconds
# drof built in 6.282537 seconds
# datm built in 7.656148 seconds
# ww built in 34.851145 seconds
# Component ice build complete with 1 warnings
# cice built in 75.216134 seconds
# Component ocn build complete with 13 warnings
# pop built in 446.682831 seconds
# Building cesm from /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/drivers/mct/cime_config/buildexe with output to /glade/scratch/bachman/smyle-fosi.North_Atlantic_basin.alk-forcing-North_Atlantic_basin.072-5year/bld/cesm.bldlog.231229-220243
# Time spent not building: 199.932244 sec
# Time spent building: 643.454660 sec
# MODEL BUILD HAS FINISHED SUCCESSFULLY
# env_batch.xml appears to have changed, regenerating batch scripts
# manual edits to these file will be lost!
# Creating batch scripts
# Writing case.run script from input template /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/config/cesm/machines/template.case.run
# Creating file .case.run
# Writing case.st_archive script from input template /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/config/cesm/machines/template.st_archive
# Creating file case.st_archive
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (307200000, -1)
# GET_REFCASE is false, the user is expected to stage the refcase to the run directory.
# Creating component namelists
#   2023-12-29 22:17:05 atm
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/datm/cime_config/buildnml
#   2023-12-29 22:17:06 lnd
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/slnd/cime_config/buildnml
#   2023-12-29 22:17:06 ice
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/cice//cime_config/buildnml
#   2023-12-29 22:17:06 ocn
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/pop//cime_config/buildnml
#   2023-12-29 22:17:09 rof
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/data_comps_mct/drof/cime_config/buildnml
#   2023-12-29 22:17:09 glc
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sglc/cime_config/buildnml
#   2023-12-29 22:17:09 wav
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/../components/ww3//cime_config/buildnml
#   2023-12-29 22:17:09 iac
#    Running /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/siac/cime_config/buildnml
#   2023-12-29 22:17:09 esp
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/components/stub_comps_mct/sesp/cime_config/buildnml
#   2023-12-29 22:17:09 cpl
#    Calling /glade/work/klindsay/cesm2_tags/cesm2.2.0/cime/src/drivers/mct/cime_config/buildnml
# Checking that inputdata is available as part of case submission
# Setting Environment OMP_STACKSIZE=1024M
# Setting Environment TMPDIR=/glade/scratch/bachman
# Setting Environment MPI_TYPE_DEPTH=16
# Setting Environment MPI_IB_CONGESTED=1
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# Loading input file list: 'Buildconf/cpl.input_data_list'
# Loading input file list: 'Buildconf/pop.input_data_list'
# Loading input file list: 'Buildconf/ww3.input_data_list'
# Loading input file list: 'Buildconf/datm.input_data_list'
# Loading input file list: 'Buildconf/drof.input_data_list'
# Loading input file list: 'Buildconf/cice.input_data_list'
# GET_REFCASE is false, the user is expected to stage the refcase to the run directory.
# GET_REFCASE is false, the user is expected to stage the refcase to the run directory.
# Creating component namelists
#   2023-12-29 22:17:11 atm
#   2023-12-29 22:17:11 lnd
#   2023-12-29 22:17:11 ice
#   2023-12-29 22:17:11 ocn
#   2023-12-29 22:17:11 rof
#   2023-12-29 22:17:11 glc
#   2023-12-29 22:17:11 wav
#   2023-12-29 22:17:11 iac
#   2023-12-29 22:17:11 esp
#   2023-12-29 22:17:11 cpl
# Check case OK
# Submitting job script qsub -q regular -l walltime=12:00:00 -A P93300612 -v ARGS_FOR_SCRIPT='--resubmit' .case.run
# Submitted job id is 4487047.chadmin1.ib0.cheyenne.ucar.edu
# Submitting job script qsub -q regular -l walltime=12:00:00 -A P93300612  -W depend=afterok:4487047.chadmin1.ib0.cheyenne.ucar.edu -v ARGS_FOR_SCRIPT='--resubmit' case.st_archive
# submit_jobs case.run
# Submit job case.run
# Submit job case.st_archive
# Submitted job id is 4487048.chadmin1.ib0.cheyenne.ucar.edu
# Submitted job case.run with id 4487047.chadmin1.ib0.cheyenne.ucar.edu
# Submitted job case.st_archive with id 4487048.chadmin1.ib0.cheyenne.ucar.edu

# %%
#FG_CO2

# %%
print('done')
# Out:
# done

# %%
######## run cesm
# clobber = True

# # use this list to run only select indexes 
# run_only_index_list = [forcing_id]  

# for n, f in enumerate(forcing_files):

#     if n not in run_only_index_list:
#         continue
#     print(n,f)

#     # string of the month: '01'
#     month_str = f[-5:-3]

#     run_settings = dict(
#         refdate="0347-" + month_str + "-01",  # change this
#         #refdate="0347-01-01",  # change this
#         stop_n=2,
#         stop_option="nyear",
#         job_queue="economy",
#         #job_queue="regular",
#         wallclock="01:00:00",
#         #wallclock="01:00:00",
#         resubmit=0, 
#     )

#     alk_forcing = os.path.basename(f).replace('.nc', '')
#     case = f"smyle-fosi.{alk_forcing_spec}.{alk_forcing}.test"

#     oae_smyle.create_clone(
#         case, 
#         alk_forcing_file=f, 
#         submit=False, 
#         clobber=clobber, 
#         curtail_output=True,
#         **run_settings
#     )
